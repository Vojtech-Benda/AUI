# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
from skfuzzy import control

# %%
doporuceni = control.Antecedent(np.arange(0, 100 + 1, 1), "doporuceni")
vzdalenost = control.Consequent(np.arange(0, 40), "vzdalenost")
cena = control.Consequent(np.arange(0, 60), "cena")

# doporuceni.automf(3)

doporuceni["low"] = fuzz.trapmf(doporuceni.universe, [0, 5, 10, 10])
doporuceni["average"] = fuzz.trapmf(doporuceni.universe, [0, 0, 20, 30])
doporuceni["high"] = fuzz.trapmf(doporuceni.universe, [0, 0, 45, 50])
#vzdalenost["low"] = fuzz.trapmf(vzdalenost.universe, [0, 0, 20, 30])
#cena["low"] = fuzz.trapmf(cena.universe, [0, 0, 45, 50])
doporuceni.view()
# Out:
# c:\Users\vojte\Desktop\skola\AUI\.venv\Lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
